# %% [markdown]
# # 1. Hello Python

# %% [markdown]
# ## 1.1 pure Python
# : 알고 있는 부분이라 생략합니다.

# %% [markdown]
# ## 1.2  Numpy

# %%
import numpy as np

# %%
x = np.array([1.0, 2.0, 3.0])
x
# Out:
# array([1., 2., 3.])

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x = np.array([1.0, 2.0, 3.0])
y = np.array([2.0, 4.0, 6.0])

# %%
x + y
# Out:
# array([3., 6., 9.])

# %%
x - y
# Out:
# array([-1., -2., -3.])

# %%
x * y
# Out:
# array([ 2.,  8., 18.])

# %%
x / y
# Out:
# array([0.5, 0.5, 0.5])

# %%
x = np.array([1.0, 2.0, 3.0])
x / 2.0
# Out:
# array([0.5, 1. , 1.5])

# %% [markdown]
# ### 1.5.4 N-dimensional array

# %%
A = np.array([[1, 2], [3, 4]])
A
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
A.shape
# Out:
# (2, 2)

# %%
A.dtype
# Out:
# dtype('int32')

# %%
B = np.array([[3, 0], [0, 6]])
B
# Out:
# array([[3, 0],
#        [0, 6]])

# %%
A + B
# Out:
# array([[ 4,  2],
#        [ 3, 10]])

# %%
A * B
# Out:
# array([[ 3,  0],
#        [ 0, 24]])

# %%
A = np.array([[1, 2], [3, 4]])
B = np.array([10, 20])
A * B
# Out:
# array([[10, 40],
#        [30, 80]])

# %% [markdown]
# ### 1.5.6 Array indexing

# %%
X = np.array([[51, 55], [14, 19], [0, 4]])
X
# Out:
# array([[51, 55],
#        [14, 19],
#        [ 0,  4]])

# %%
X[0]
# Out:
# array([51, 55])

# %%
X[0][1]
# Out:
# 55

# %%
for row in X:
    print(row)
# Out:
# [51 55]
# [14 19]
# [0 4]

# %% [markdown]
# ### futher study

# %%
import numpy as np
array = np.array([[1,2,3,4],[3,4,2,5]])

# %%
array
# Out:
# array([[1, 2, 3, 4],
#        [3, 4, 2, 5]])

# %%
import pandas as pd
pd.DataFrame(array)
# Out:
#    0  1  2  3
# 0  1  2  3  4
# 1  3  4  2  5

# %% [markdown]
# ## 1.6 Matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1) # 0에서 6까지 0.1 간격으로 생성
y = np.sin(x)

# 그래프 그리기
plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1)
y1 = np.sin(x)
y2 = np.cos(x)

# 그래프 그리기
plt.plot(x,y1, label = "sin")
plt.plot(x,y2, linestyle = "--",label = "cos")
plt.xlabel("x")
plt.ylabel("y")
plt.title('sin & cos')
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('../resource/image/data_scientist.png')

plt.imshow(img)

plt.title("data scientist")
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

img = imread('../resource/image/Lenna.png')

plt.imshow(img)

plt.title("Lenna")
plt.show()
