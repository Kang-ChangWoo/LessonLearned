# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = [0,0,1,1]
y = [0,1,0,1]

def functionOR(x_, y_):
    return x_*1.0 + y_*1.0 - 0.5

x__ = np.arange(-10,10,1)
y__ = np.arange(-10,10,1)

# for i in range(len(x)):
#     plt.scatter(x, y)
    
for i in range(len(x__)):
    plt.scatter(x__[i], functionOR(x__[i],y__[i]))

plt.show()

# %%
x.size
# Out:
# 10

# %%
x = np.arange(-5,5,1)
y = np.zeros(x.size)
plt.plot(x, -1*x + 0.5, label = 'y = {}x'.format(i))

# plt.plot(x, 0)
plt.plot(x, y, color='k')
plt.plot(y, x, color='k')
plt.scatter(0,0)
plt.scatter(0,0)
plt.scatter(0,1)
plt.scatter(1,0)
plt.scatter(1,1)
plt.grid()
plt.legend(fontsize = 15, loc = 8)
